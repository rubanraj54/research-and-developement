# %%
# %run 'log_parser_util.ipynb'

# %% [markdown]
# # Write only mode

# %%
couchdb_files_write_1 = open_files(3)
couchdb_files_write_2 = open_files(3)
couchdb_files_write_3 = open_files(3)

# %%
couchdb_files_write_1 = ['/home/ruby/Desktop/logs/couchdb/executionlogs1/write/30.0HZ/write_2017-11-26 11:46:01_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/write/60.0HZ/write_2017-11-26 12:02:36_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/write/120.0HZ/write_2017-11-26 20:34:30_120.0_hz.log']

# %%
couchdb_files_write_2 = ['/home/ruby/Desktop/logs/couchdb/executionlogs2/write/30.0HZ/write_2017-11-26 11:46:05_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/write/60.0HZ/write_2017-11-26 12:02:38_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/write/120.0HZ/write_2017-11-26 20:34:31_120.0_hz.log']

# %%
couchdb_files_write_3 = ['/home/ruby/Desktop/logs/couchdb/executionlogs3/write/30.0HZ/write_2017-11-26 11:46:06_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/write/60.0HZ/write_2017-11-26 12:02:41_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/write/120.0HZ/write_2017-11-26 20:34:33_120.0_hz.log']

# %%
couchdb_avgs_write_1 = get_avg(couchdb_files_write_1)
couchdb_df_write_1 = pd.DataFrame(couchdb_avgs_write_1, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_write_2 = get_avg(couchdb_files_write_2)
couchdb_df_write_2 = pd.DataFrame(couchdb_avgs_write_2, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_write_3 = get_avg(couchdb_files_write_3)
couchdb_df_write_3 = pd.DataFrame(couchdb_avgs_write_3, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

# %%
plot("Average write query execution timings - CouchDB database (Robot 1)",1,couchdb_df_write_1)
plot("Average write query execution timings - CouchDB database (Robot 2)",1,couchdb_df_write_2)
plot("Average write query execution timings - CouchDB database (Robot 3)",1,couchdb_df_write_3)

# %%
print "Average write query execution timings - CouchDB database (Robot 1)"
HTML(couchdb_df_write_1.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write query execution timings - CouchDB database (Robot 1)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.081087</td>
#       <td>0.080903</td>
#       <td>0.080629</td>
#       <td>0.081114</td>
#       <td>0.080846</td>
#       <td>0.149058</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.082515</td>
#       <td>0.081947</td>
#       <td>0.081922</td>
#       <td>0.082146</td>
#       <td>0.081887</td>
#       <td>0.154674</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.086114</td>
#       <td>0.086379</td>
#       <td>0.086169</td>
#       <td>0.086284</td>
#       <td>0.085920</td>
#       <td>0.170642</td>
# ...

# %%
print "Average write query execution timings - CouchDB database (Robot 2)"
HTML(couchdb_df_write_2.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write query execution timings - CouchDB database (Robot 2)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.083198</td>
#       <td>0.082940</td>
#       <td>0.082826</td>
#       <td>0.083010</td>
#       <td>0.082860</td>
#       <td>0.148917</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.084586</td>
#       <td>0.084618</td>
#       <td>0.084727</td>
#       <td>0.084469</td>
#       <td>0.084766</td>
#       <td>0.155909</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.089151</td>
#       <td>0.089142</td>
#       <td>0.088991</td>
#       <td>0.088962</td>
#       <td>0.089025</td>
#       <td>0.171343</td>
# ...

# %%
print "Average write query execution timings - CouchDB database (Robot 3)"
HTML(couchdb_df_write_3.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write query execution timings - CouchDB database (Robot 3)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.083144</td>
#       <td>0.082972</td>
#       <td>0.083058</td>
#       <td>0.083303</td>
#       <td>0.083117</td>
#       <td>0.144817</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.084627</td>
#       <td>0.084864</td>
#       <td>0.084983</td>
#       <td>0.084506</td>
#       <td>0.084678</td>
#       <td>0.156792</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.088849</td>
#       <td>0.088708</td>
#       <td>0.088676</td>
#       <td>0.088400</td>
#       <td>0.088546</td>
#       <td>0.169187</td>
# ...

# %% [markdown]
# # Read only mode

# %%
couchdb_files_read_1 = open_files(3)
couchdb_files_read_2 = open_files(3)
couchdb_files_read_3 = open_files(3)

# %%
couchdb_files_read_1 = ['/home/ruby/Desktop/logs/couchdb/executionlogs1/read/30.0HZ/read_2017-11-26 21:03:47_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/read/60.0HZ/read_2017-11-26 21:15:08_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/read/120.0HZ/read_2017-11-26 21:26:18_120.0_hz.log']

# %%
couchdb_files_read_2 = ['/home/ruby/Desktop/logs/couchdb/executionlogs2/read/30.0HZ/read_2017-11-26 21:03:49_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/read/60.0HZ/read_2017-11-26 21:15:10_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/read/120.0HZ/read_2017-11-26 21:26:21_120.0_hz.log']

# %%
couchdb_files_read_3 = ['/home/ruby/Desktop/logs/couchdb/executionlogs3/read/30.0HZ/read_2017-11-26 21:03:55_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/read/60.0HZ/read_2017-11-26 21:15:06_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/read/120.0HZ/read_2017-11-26 21:26:16_120.0_hz.log']

# %%
couchdb_avgs_read_1 = get_avg_read(couchdb_files_read_1)
couchdb_df_read_1 = pd.DataFrame(couchdb_avgs_read_1, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_read_2 = get_avg_read(couchdb_files_read_2)
couchdb_df_read_2 = pd.DataFrame(couchdb_avgs_read_2, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_read_3 = get_avg_read(couchdb_files_read_3)
couchdb_df_read_3 = pd.DataFrame(couchdb_avgs_read_3, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

# %%
plot("Average read query execution timings - CouchDB database (Robot 1)",1,couchdb_df_read_1)
plot("Average read query execution timings - CouchDB database (Robot 2)",1,couchdb_df_read_2)
plot("Average read query execution timings - CouchDB database (Robot 3)",1,couchdb_df_read_3)

# %%
print "Average read query execution timings - CouchDB database (Robot 1)"
HTML(couchdb_df_read_1.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings - CouchDB database (Robot 1)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.000225</td>
#       <td>0.000223</td>
#       <td>0.000222</td>
#       <td>0.000220</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.000210</td>
#       <td>0.000209</td>
#       <td>0.000207</td>
#       <td>0.000206</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.000191</td>
#       <td>0.000192</td>
#       <td>0.000189</td>
#       <td>0.000189</td>
#     </tr>
#   </tbody>
# </table>

# %%
print "Average read query execution timings - CouchDB database (Robot 2)"
HTML(couchdb_df_read_2.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings - CouchDB database (Robot 2)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.000226</td>
#       <td>0.000224</td>
#       <td>0.000222</td>
#       <td>0.000222</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.000207</td>
#       <td>0.000209</td>
#       <td>0.000207</td>
#       <td>0.000204</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.000192</td>
#       <td>0.000191</td>
#       <td>0.000191</td>
#       <td>0.000188</td>
#     </tr>
#   </tbody>
# </table>

# %%
print "Average read query execution timings - CouchDB database (Robot 3)"
HTML(couchdb_df_read_3.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings - CouchDB database (Robot 3)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.000225</td>
#       <td>0.000223</td>
#       <td>0.000220</td>
#       <td>0.000219</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.000208</td>
#       <td>0.000208</td>
#       <td>0.000206</td>
#       <td>0.000203</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.000189</td>
#       <td>0.000190</td>
#       <td>0.000189</td>
#       <td>0.000185</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Write with read mode

# %%
couchdb_files_rw_write_1 = open_files(3)
couchdb_files_rw_write_2 = open_files(3)
couchdb_files_rw_write_3 = open_files(3)

# %%
couchdb_files_rw_write_1 = ['/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_write/30.0HZ/rw_write_2017-11-26 22:06:03_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_write/60.0HZ/rw_write_2017-11-26 22:20:19_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_write/120.0HZ/rw_write_2017-11-26 22:35:21_120.0_hz.log']

# %%
couchdb_files_rw_write_2 = ['/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_write/30.0HZ/rw_write_2017-11-26 22:06:08_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_write/60.0HZ/rw_write_2017-11-26 22:20:20_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_write/120.0HZ/rw_write_2017-11-26 22:35:23_120.0_hz.log']

# %%
couchdb_files_rw_write_3 = ['/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_write/30.0HZ/rw_write_2017-11-26 22:06:06_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_write/60.0HZ/rw_write_2017-11-26 22:20:16_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_write/120.0HZ/rw_write_2017-11-26 22:35:25_120.0_hz.log']

# %%
couchdb_avgs_rw_write_1 = get_avg(couchdb_files_rw_write_1)
couchdb_df_write_1 = pd.DataFrame(couchdb_avgs_rw_write_1, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_rw_write_2 = get_avg(couchdb_files_rw_write_2)
couchdb_df_write_2 = pd.DataFrame(couchdb_avgs_rw_write_2, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_rw_write_3 = get_avg(couchdb_files_rw_write_3)
couchdb_df_write_3 = pd.DataFrame(couchdb_avgs_rw_write_3, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

# %%
plot("Average write along with read query execution timings - CouchDB database (Robot 1)",1,couchdb_df_write_1)
plot("Average write along with read query execution timings - CouchDB database (Robot 2)",1,couchdb_df_write_2)
plot("Average write along with read query execution timings - CouchDB database (Robot 3)",1,couchdb_df_write_3)

# %%
print "Average write along with read query execution timings - CouchDB database (Robot 1)"
HTML(couchdb_df_write_1.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write along with read query execution timings - CouchDB database (Robot 1)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.087760</td>
#       <td>0.087635</td>
#       <td>0.087845</td>
#       <td>0.087897</td>
#       <td>0.088157</td>
#       <td>0.159263</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.090267</td>
#       <td>0.090472</td>
#       <td>0.090356</td>
#       <td>0.090119</td>
#       <td>0.089966</td>
#       <td>0.174849</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.097377</td>
#       <td>0.097236</td>
#       <td>0.097456</td>
#       <td>0.097636</td>
#       <td>0.097698</td>
# ...

# %%
print "Average write along with read query execution timings - CouchDB database (Robot 2)"
HTML(couchdb_df_write_2.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write along with read query execution timings - CouchDB database (Robot 2)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.090905</td>
#       <td>0.090178</td>
#       <td>0.090172</td>
#       <td>0.090594</td>
#       <td>0.090471</td>
#       <td>0.160235</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.093132</td>
#       <td>0.092757</td>
#       <td>0.092573</td>
#       <td>0.092796</td>
#       <td>0.092494</td>
#       <td>0.170381</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.100346</td>
#       <td>0.099820</td>
#       <td>0.100515</td>
#       <td>0.099768</td>
#       <td>0.100122</td>
# ...

# %%
print "Average write along with read query execution timings - CouchDB database (Robot 3)"
HTML(couchdb_df_write_3.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write along with read query execution timings - CouchDB database (Robot 3)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.090657</td>
#       <td>0.090402</td>
#       <td>0.090507</td>
#       <td>0.090252</td>
#       <td>0.090689</td>
#       <td>0.162742</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.092469</td>
#       <td>0.092304</td>
#       <td>0.092333</td>
#       <td>0.092573</td>
#       <td>0.091726</td>
#       <td>0.173313</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.100121</td>
#       <td>0.099725</td>
#       <td>0.100229</td>
#       <td>0.100258</td>
#       <td>0.099795</td>
# ...

# %% [markdown]
# Note:
#
# By comparing "write with read" scenario and "write only scenario", it shows that "write with read" query execution time is increased 15% compared to "write only scenario"

# %% [markdown]
# # Read with write mode

# %%
couchdb_files_rw_read_1 = open_files(3)
couchdb_files_rw_read_2 = open_files(3)
couchdb_files_rw_read_3 = open_files(3)

# %%
couchdb_files_rw_read_1 = ['/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_read/30.0HZ/rw_read_2017-11-26 22:06:05_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_read/60.0HZ/rw_read_2017-11-26 22:20:17_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_read/120.0HZ/rw_read_2017-11-26 22:35:22_120.0_hz.log']

# %%
couchdb_files_rw_read_2 = ['/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_read/30.0HZ/rw_read_2017-11-26 22:06:10_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_read/60.0HZ/rw_read_2017-11-26 22:20:22_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_read/120.0HZ/rw_read_2017-11-26 22:35:24_120.0_hz.log']

# %%
couchdb_files_rw_read_3 = ['/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_read/30.0HZ/rw_read_2017-11-26 22:06:07_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_read/60.0HZ/rw_read_2017-11-26 22:20:15_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_read/120.0HZ/rw_read_2017-11-26 22:35:26_120.0_hz.log']

# %%
couchdb_avgs_rw_read_1 = get_avg_read(couchdb_files_rw_read_1)
couchdb_df_rw_read_1 = pd.DataFrame(couchdb_avgs_rw_read_1, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_rw_read_2 = get_avg_read(couchdb_files_rw_read_2)
couchdb_df_rw_read_2 = pd.DataFrame(couchdb_avgs_rw_read_2, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_rw_read_3 = get_avg_read(couchdb_files_rw_read_3)
couchdb_df_rw_read_3 = pd.DataFrame(couchdb_avgs_rw_read_3, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

# %%
plot("Average read query execution timings - CouchDB database (Robot 1)",1,couchdb_df_rw_read_1)
plot("Average read query execution timings - CouchDB database (Robot 2)",1,couchdb_df_rw_read_2)
plot("Average read query execution timings - CouchDB database (Robot 3)",1,couchdb_df_rw_read_3)

# %%
print "Average read query execution timings with write operation- CouchDB database (Robot 1)"
HTML(couchdb_df_rw_read_1.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings with write operation- CouchDB database (Robot 1)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.000093</td>
#       <td>0.000093</td>
#       <td>0.000093</td>
#       <td>0.000095</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.000087</td>
#       <td>0.000089</td>
#       <td>0.000089</td>
#       <td>0.000088</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.000086</td>
#       <td>0.000087</td>
#       <td>0.000087</td>
#       <td>0.000086</td>
#     </tr>
#   </tbody>
# </table>

# %%
print "Average read query execution timings with write operation- CouchDB database (Robot 2)"
HTML(couchdb_df_rw_read_2.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings with write operation- CouchDB database (Robot 2)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.000092</td>
#       <td>0.000090</td>
#       <td>0.000089</td>
#       <td>0.000089</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.000085</td>
#       <td>0.000084</td>
#       <td>0.000086</td>
#       <td>0.000084</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.000087</td>
#       <td>0.000086</td>
#       <td>0.000086</td>
#       <td>0.000088</td>
#     </tr>
#   </tbody>
# </table>

# %%
print "Average read query execution timings with write operation- CouchDB database (Robot 3)"
HTML(couchdb_df_rw_read_3.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings with write operation- CouchDB database (Robot 3)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.000089</td>
#       <td>0.000090</td>
#       <td>0.000088</td>
#       <td>0.000091</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.000088</td>
#       <td>0.000087</td>
#       <td>0.000087</td>
#       <td>0.000088</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.000086</td>
#       <td>0.000087</td>
#       <td>0.000086</td>
#       <td>0.000086</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observation:**
#
# Read with write query execution timings are more or less similar for all four type of queries, but in read only scenario, the execution times are not similar.
#
# And also observed that, in read with write mode the execution time is **50% less** than read only mode.
