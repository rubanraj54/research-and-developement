# %% [markdown]
# # Cassandra

# %%
# %run 'log_parser_util.ipynb'

# %% [markdown]
# # Write only mode

# %%
cassandra_files_write_1 = open_files(3)
cassandra_files_write_2 = open_files(3)
cassandra_files_write_3 = open_files(3)

# %%
cassandra_files_write_1 = ['/home/ruby/Desktop/logs/cassandra/executionlogs1/write/30.0HZ/write_2017-12-03 17:34:07_30.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs1/write/60.0HZ/write_2017-12-03 18:00:32_60.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs1/write/120.0HZ/write_2017-12-03 20:30:59_120.0_hz.log']

# %%
cassandra_files_write_2 = ['/home/ruby/Desktop/logs/cassandra/executionlogs2/write/30.0HZ/write_2017-12-03 17:34:10_30.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs2/write/60.0HZ/write_2017-12-03 18:00:33_60.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs2/write/120.0HZ/write_2017-12-03 20:31:00_120.0_hz.log']

# %%
cassandra_files_write_3 = ['/home/ruby/Desktop/logs/cassandra/executionlogs3/write/30.0HZ/write_2017-12-03 17:34:13_30.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs3/write/60.0HZ/write_2017-12-03 18:00:35_60.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs3/write/120.0HZ/write_2017-12-03 20:31:01_120.0_hz.log']

# %%
cassandra_avgs_write_1 = get_avg(cassandra_files_write_1)
cassandra_df_write_1 = pd.DataFrame(cassandra_avgs_write_1, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

cassandra_avgs_write_2 = get_avg(cassandra_files_write_2)
cassandra_df_write_2 = pd.DataFrame(cassandra_avgs_write_2, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

cassandra_avgs_write_3 = get_avg(cassandra_files_write_3)
cassandra_df_write_3 = pd.DataFrame(cassandra_avgs_write_3, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

# %%
plot("Average write query execution timings - Cassandra database (Robot 1)",1,cassandra_df_write_1)
plot("Average write query execution timings - Cassandra database (Robot 2)",1,cassandra_df_write_2)
plot("Average write query execution timings - Cassandra database (Robot 3)",1,cassandra_df_write_3)

# %%
print "Average write query execution timings - Cassandra database (Robot 1)"
HTML(cassandra_df_write_1.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write query execution timings - Cassandra database (Robot 1)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.005451</td>
#       <td>0.005257</td>
#       <td>0.005369</td>
#       <td>0.005238</td>
#       <td>0.007531</td>
#       <td>0.041166</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.006134</td>
#       <td>0.005342</td>
#       <td>0.005973</td>
#       <td>0.005576</td>
#       <td>0.005170</td>
#       <td>0.049370</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.013155</td>
#       <td>0.012653</td>
#       <td>0.013397</td>
#       <td>0.013151</td>
#       <td>0.013040</td>
#       <td>0.063712</td>
# ...

# %%
print "Average write query execution timings - Cassandra database (Robot 2)"
HTML(cassandra_df_write_2.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write query execution timings - Cassandra database (Robot 2)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.008243</td>
#       <td>0.007294</td>
#       <td>0.008543</td>
#       <td>0.006694</td>
#       <td>0.008640</td>
#       <td>0.049814</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.006659</td>
#       <td>0.006525</td>
#       <td>0.006911</td>
#       <td>0.007174</td>
#       <td>0.006661</td>
#       <td>0.048860</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.015749</td>
#       <td>0.015708</td>
#       <td>0.015947</td>
#       <td>0.015194</td>
#       <td>0.015484</td>
#       <td>0.055718</td>
# ...

# %%
print "Average write query execution timings - Cassandra database (Robot 3)"
HTML(cassandra_df_write_3.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write query execution timings - Cassandra database (Robot 3)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.007032</td>
#       <td>0.007918</td>
#       <td>0.007156</td>
#       <td>0.007577</td>
#       <td>0.007975</td>
#       <td>0.056138</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.006988</td>
#       <td>0.007028</td>
#       <td>0.006820</td>
#       <td>0.006953</td>
#       <td>0.007056</td>
#       <td>0.053456</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.021852</td>
#       <td>0.021529</td>
#       <td>0.021306</td>
#       <td>0.021622</td>
#       <td>0.021386</td>
#       <td>0.061526</td>
# ...

# %% [markdown]
# # Read only mode

# %%
cassandra_files_read_1 = open_files(3)
cassandra_files_read_2 = open_files(3)
cassandra_files_read_3 = open_files(3)

# %%
cassandra_files_read_1 = ['/home/ruby/Desktop/logs/cassandra/executionlogs1/read/30.0HZ/read_2017-12-03 20:54:35_30.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs1/read/60.0HZ/read_2017-12-03 21:05:48_60.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs1/read/120.0HZ/read_2017-12-03 21:19:01_120.0_hz.log']

# %%
cassandra_files_read_2 = ['/home/ruby/Desktop/logs/cassandra/executionlogs2/read/30.0HZ/read_2017-12-03 20:54:53_30.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs2/read/60.0HZ/read_2017-12-03 21:05:50_60.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs2/read/120.0HZ/read_2017-12-03 21:19:03_120.0_hz.log']

# %%
cassandra_files_read_3 = ['/home/ruby/Desktop/logs/cassandra/executionlogs3/read/30.0HZ/read_2017-12-03 20:54:39_30.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs3/read/60.0HZ/read_2017-12-03 21:19:04_60.0_hz.log',
 '/home/ruby/Desktop/logs/cassandra/executionlogs3/read/60.0HZ/read_2017-12-03 21:05:46_60.0_hz.log']

# %%
cassandra_avgs_read_1 = get_avg_read(cassandra_files_read_1)
cassandra_df_read_1 = pd.DataFrame(cassandra_avgs_read_1, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

cassandra_avgs_read_2 = get_avg_read(cassandra_files_read_2)
cassandra_df_read_2 = pd.DataFrame(cassandra_avgs_read_2, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

cassandra_avgs_read_3 = get_avg_read(cassandra_files_read_3)
cassandra_df_read_3 = pd.DataFrame(cassandra_avgs_read_3, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

# %%
plot("Average read query execution timings - Cassandra database (Robot 1)",1,cassandra_df_read_1)
plot("Average read query execution timings - Cassandra database (Robot 2)",1,cassandra_df_read_2)
plot("Average read query execution timings - Cassandra database (Robot 3)",1,cassandra_df_read_3)

# %%
print "Average read query execution timings - Cassandra database (Robot 1)"
HTML(cassandra_df_read_1.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings - CouchDB database (Robot 1)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.000962</td>
#       <td>0.000950</td>
#       <td>1.991732</td>
#       <td>0.000591</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.000920</td>
#       <td>0.000941</td>
#       <td>2.174306</td>
#       <td>0.000617</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.001361</td>
#       <td>0.001375</td>
#       <td>2.838716</td>
#       <td>0.000910</td>
#     </tr>
#   </tbody>
# </table>

# %%
print "Average read query execution timings - Cassandra database (Robot 2)"
HTML(cassandra_df_read_2.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings - Cassandra database (Robot 2)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.001155</td>
#       <td>0.001164</td>
#       <td>2.215867</td>
#       <td>0.000726</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.001053</td>
#       <td>0.001071</td>
#       <td>2.404288</td>
#       <td>0.000696</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.001374</td>
#       <td>0.001382</td>
#       <td>3.102541</td>
#       <td>0.000908</td>
#     </tr>
#   </tbody>
# </table>

# %%
print "Average read query execution timings - Cassandra database (Robot 3)"
HTML(cassandra_df_read_3.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings - Cassandra database (Robot 3)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.001120</td>
#       <td>0.001069</td>
#       <td>2.240158</td>
#       <td>0.000704</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.001266</td>
#       <td>0.001252</td>
#       <td>2.295575</td>
#       <td>0.000850</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.001094</td>
#       <td>0.001086</td>
#       <td>2.407969</td>
#       <td>0.000683</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Write with read mode

# %%
couchdb_files_rw_write_1 = open_files(3)
couchdb_files_rw_write_2 = open_files(3)
couchdb_files_rw_write_3 = open_files(3)

# %%
couchdb_files_rw_write_1 = ['/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_write/30.0HZ/rw_write_2017-11-26 22:06:03_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_write/60.0HZ/rw_write_2017-11-26 22:20:19_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_write/120.0HZ/rw_write_2017-11-26 22:35:21_120.0_hz.log']

# %%
couchdb_files_rw_write_2 = ['/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_write/30.0HZ/rw_write_2017-11-26 22:06:08_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_write/60.0HZ/rw_write_2017-11-26 22:20:20_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_write/120.0HZ/rw_write_2017-11-26 22:35:23_120.0_hz.log']

# %%
couchdb_files_rw_write_3 = ['/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_write/30.0HZ/rw_write_2017-11-26 22:06:06_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_write/60.0HZ/rw_write_2017-11-26 22:20:16_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_write/120.0HZ/rw_write_2017-11-26 22:35:25_120.0_hz.log']

# %%
couchdb_avgs_rw_write_1 = get_avg(couchdb_files_rw_write_1)
couchdb_df_rw_write_1 = pd.DataFrame(couchdb_avgs_rw_write_1, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_rw_write_2 = get_avg(couchdb_files_rw_write_2)
couchdb_df_rw_write_2 = pd.DataFrame(couchdb_avgs_rw_write_2, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_rw_write_3 = get_avg(couchdb_files_rw_write_3)
couchdb_df_rw_write_3 = pd.DataFrame(couchdb_avgs_rw_write_3, columns=['Event-1', 'Event-2', 'Event-3', 'Event-4','Event-5','Event-6'],
                   index=['30hz','60hz','120hz'])

# %%
plot("Average write along with read query execution timings - CouchDB database (Robot 1)",1,couchdb_df_rw_write_1)
plot("Average write along with read query execution timings - CouchDB database (Robot 2)",1,couchdb_df_rw_write_2)
plot("Average write along with read query execution timings - CouchDB database (Robot 3)",1,couchdb_df_rw_write_3)

# %%
print "Average write along with read query execution timings - CouchDB database (Robot 1)"
HTML(couchdb_df_rw_write_1.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write along with read query execution timings - CouchDB database (Robot 1)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.087760</td>
#       <td>0.087635</td>
#       <td>0.087845</td>
#       <td>0.087897</td>
#       <td>0.088157</td>
#       <td>0.159263</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.090267</td>
#       <td>0.090472</td>
#       <td>0.090356</td>
#       <td>0.090119</td>
#       <td>0.089966</td>
#       <td>0.174849</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.097377</td>
#       <td>0.097236</td>
#       <td>0.097456</td>
#       <td>0.097636</td>
#       <td>0.097698</td>
# ...

# %%
print "Average write along with read query execution timings - CouchDB database (Robot 2)"
HTML(couchdb_df_rw_write_2.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write along with read query execution timings - CouchDB database (Robot 2)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.090905</td>
#       <td>0.090178</td>
#       <td>0.090172</td>
#       <td>0.090594</td>
#       <td>0.090471</td>
#       <td>0.160235</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.093132</td>
#       <td>0.092757</td>
#       <td>0.092573</td>
#       <td>0.092796</td>
#       <td>0.092494</td>
#       <td>0.170381</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.100346</td>
#       <td>0.099820</td>
#       <td>0.100515</td>
#       <td>0.099768</td>
#       <td>0.100122</td>
# ...

# %%
print "Average write along with read query execution timings - CouchDB database (Robot 3)"
HTML(couchdb_df_rw_write_3.to_html(classes="table table-striped table-bordered"))
# Out:
# Average write along with read query execution timings - CouchDB database (Robot 3)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Event-1</th>
#       <th>Event-2</th>
#       <th>Event-3</th>
#       <th>Event-4</th>
#       <th>Event-5</th>
#       <th>Event-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.090657</td>
#       <td>0.090402</td>
#       <td>0.090507</td>
#       <td>0.090252</td>
#       <td>0.090689</td>
#       <td>0.162742</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.092469</td>
#       <td>0.092304</td>
#       <td>0.092333</td>
#       <td>0.092573</td>
#       <td>0.091726</td>
#       <td>0.173313</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.100121</td>
#       <td>0.099725</td>
#       <td>0.100229</td>
#       <td>0.100258</td>
#       <td>0.099795</td>
# ...

# %% [markdown]
# Note:
#
# By comparing "write with read" scenario and "write only scenario", it shows that "write with read" query execution time is increased 15% compared to "write only scenario"

# %% [markdown]
# # Read with write mode

# %%
couchdb_files_rw_read_1 = open_files(3)
couchdb_files_rw_read_2 = open_files(3)
couchdb_files_rw_read_3 = open_files(3)

# %%
couchdb_files_rw_read_1 = ['/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_read/30.0HZ/rw_read_2017-11-26 22:06:05_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_read/60.0HZ/rw_read_2017-11-26 22:20:17_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs1/rw_read/120.0HZ/rw_read_2017-11-26 22:35:22_120.0_hz.log']

# %%
couchdb_files_rw_read_2 = ['/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_read/30.0HZ/rw_read_2017-11-26 22:06:10_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_read/60.0HZ/rw_read_2017-11-26 22:20:22_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs2/rw_read/120.0HZ/rw_read_2017-11-26 22:35:24_120.0_hz.log']

# %%
couchdb_files_rw_read_3 = ['/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_read/30.0HZ/rw_read_2017-11-26 22:06:07_30.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_read/60.0HZ/rw_read_2017-11-26 22:20:15_60.0_hz.log',
 '/home/ruby/Desktop/logs/couchdb/executionlogs3/rw_read/120.0HZ/rw_read_2017-11-26 22:35:26_120.0_hz.log']

# %%
couchdb_avgs_rw_read_1 = get_avg_read(couchdb_files_rw_read_1)
couchdb_df_rw_read_1 = pd.DataFrame(couchdb_avgs_rw_read_1, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_rw_read_2 = get_avg_read(couchdb_files_rw_read_2)
couchdb_df_rw_read_2 = pd.DataFrame(couchdb_avgs_rw_read_2, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

couchdb_avgs_rw_read_3 = get_avg_read(couchdb_files_rw_read_3)
couchdb_df_rw_read_3 = pd.DataFrame(couchdb_avgs_rw_read_3, columns=['Query-1', 'Query-2', 'Query-3', 'Query-4'],
                   index=['30hz','60hz','120hz'])

# %%
plot("Average read query execution timings - CouchDB database (Robot 1)",1,couchdb_df_rw_read_1)
plot("Average read query execution timings - CouchDB database (Robot 2)",1,couchdb_df_rw_read_2)
plot("Average read query execution timings - CouchDB database (Robot 3)",1,couchdb_df_rw_read_3)

# %%
print "Average read query execution timings with write operation- CouchDB database (Robot 1)"
HTML(couchdb_df_rw_read_1.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings with write operation- CouchDB database (Robot 1)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.000093</td>
#       <td>0.000093</td>
#       <td>0.000093</td>
#       <td>0.000095</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.000087</td>
#       <td>0.000089</td>
#       <td>0.000089</td>
#       <td>0.000088</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.000086</td>
#       <td>0.000087</td>
#       <td>0.000087</td>
#       <td>0.000086</td>
#     </tr>
#   </tbody>
# </table>

# %%
print "Average read query execution timings with write operation- CouchDB database (Robot 2)"
HTML(couchdb_df_rw_read_2.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings with write operation- CouchDB database (Robot 2)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.000092</td>
#       <td>0.000090</td>
#       <td>0.000089</td>
#       <td>0.000089</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.000085</td>
#       <td>0.000084</td>
#       <td>0.000086</td>
#       <td>0.000084</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.000087</td>
#       <td>0.000086</td>
#       <td>0.000086</td>
#       <td>0.000088</td>
#     </tr>
#   </tbody>
# </table>

# %%
print "Average read query execution timings with write operation- CouchDB database (Robot 3)"
HTML(couchdb_df_rw_read_3.to_html(classes="table table-striped table-bordered"))
# Out:
# Average read query execution timings with write operation- CouchDB database (Robot 3)
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Query-1</th>
#       <th>Query-2</th>
#       <th>Query-3</th>
#       <th>Query-4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30hz</th>
#       <td>0.000089</td>
#       <td>0.000090</td>
#       <td>0.000088</td>
#       <td>0.000091</td>
#     </tr>
#     <tr>
#       <th>60hz</th>
#       <td>0.000088</td>
#       <td>0.000087</td>
#       <td>0.000087</td>
#       <td>0.000088</td>
#     </tr>
#     <tr>
#       <th>120hz</th>
#       <td>0.000086</td>
#       <td>0.000087</td>
#       <td>0.000086</td>
#       <td>0.000086</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observation:**
#
# Read with write query execution timings are more or less similar for all four type of queries, but in read only scenario, the execution times are not similar.
#
# And also observed that, in read with write mode the execution time is **50% less** than read only mode.

# %% [markdown]
# # Average Replication Time:

# %%
files = open_files(2)

# %%
#CouchDB replication time
get_replica_results(files)
# Out:
# 'Average time to replicate an event from one data node to other is, 0.4733 seconds'
