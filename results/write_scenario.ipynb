# %%
# %run 'util.ipynb'

# %% [markdown]
# ###### Event1: Location Event
# ```
# {
#     'latitude' : random.uniform(1.0, 100.0), #float 24bytes
#     'longitude' : random.uniform(1.0, 100.0), #float 24bytes
#     'offset' : random.uniform(1.0, 100.0), #float 24bytes
#     'accuracy' : random.uniform(1.0, 100.0), #float 24bytes
#     'timestamp' : datetime.datetime.now() #datetime 48bytes
# }
# ```

# %%
databases = ["neo4j","orientdb","couchdb","mongodb","cassandra","arangodb","influxdb","mysql"]
event_1 = get_avg_write(["write","rw_write"],["Event_id: 1","Event : 0"],databases)

# %%
event_1
# Out:
#                          neo4j  orientdb  couchdb  mongodb  cassandra  \
# write(30hz)             0.0900    0.0074   0.0792   0.0035     0.0041
# write_with_read(30hz)   0.0857    0.0076   0.0854   0.0027     0.0100
# write(60hz)             0.0824    0.0095   0.0806   0.0036     0.0047
# write_with_read(60hz)   0.0841    0.0097   0.0879   0.0045     0.0114
# write(120hz)            0.0724    0.0094   0.0835   0.0038     0.0112
# write_with_read(120hz)  0.0632    0.0102   0.0947   0.0021     0.0242
#
#                         arangodb  influxdb   mysql
# write(30hz)               0.0016    0.0114  0.0113
# write_with_read(30hz)     0.0082    0.0227  0.0129
# write(60hz)               0.0017    0.0116  0.0133
# write_with_read(60hz)     0.0018    0.0331  0.0142
# write(120hz)              0.0127    0.0068  0.0129
# write_with_read(120hz)    0.0152    0.0385  0.0161

# %%
event_1.std(axis=0)
# Out:
# neo4j        0.009942
# orientdb     0.001171
# couchdb      0.005615
# mongodb      0.000848
# cassandra    0.007249
# arangodb     0.006089
# influxdb     0.012939
# mysql        0.001602
# dtype: float64

# %%
plot(event_1,"Average write query execution timings for Location Event")
# Out:
# write(30hz)               0.036416
# write_with_read(30hz)     0.035126
# write(60hz)               0.034536
# write_with_read(60hz)     0.035328
# write(120hz)              0.031984
# write_with_read(120hz)    0.031405
# dtype: float64

# %% [markdown]
# # Event2: HandleBarVoltage Event
# ```
# {
#     'voltage' : random.uniform(1.0, 100.0), #float 24bytes
#     'timestamp' : datetime.datetime.now() #datetime 48bytes
# }
# ```

# %%
event_2 = get_avg_write(["write","rw_write"],["Event_id: 2","Event : 1"],databases)

# %%
plot(event_2,"Average write query execution timings for HandleBarVoltage Event")

# %% [markdown]
# # Event3: MototBarVoltage Event
# ```
# {
#     'motor_id' : random.randint(1, 10), #float 24bytes
#     'voltage' : random.uniform(1.0, 100.0), #float 24bytes
#     'current' : random.uniform(1.0, 100.0), #float 24bytes
#     'timestamp' : datetime.datetime.now() #datetime 48bytes
# }
# ```

# %%
event_3 = get_avg_write(["write","rw_write"],["Event_id: 3","Event : 2"],databases)

# %%
plot(event_3,"Average write query execution timings for MotorBarVoltage Event")

# %% [markdown]
# # Event4: Pose Event
# ```
# {
#     'x' : random.uniform(1.0, 100.0), #float 24bytes
#     'y' : random.uniform(1.0, 100.0), #float 24bytes
#     'z' : random.uniform(1.0, 100.0), #float 24bytes
#     'theta' : random.uniform(1.0, 100.0), #float 24bytes
#     'timestamp' : datetime.datetime.now() #datetime 48bytes
# }
# ```

# %%
event_4 = get_avg_write(["write","rw_write"],["Event_id: 4","Event : 3"],databases)

# %%
plot(event_4,"Average write query execution timings for Pose Event")

# %% [markdown]
# # Event5: RGB Event (without blob)
# ```
# {
#     'image_base64': big_image_base64_path, #string >60bytes
#     'blob' : False, #boolean 24bytes
#     'timestamp' : datetime.datetime.now() #datetime 48bytes
# }
# ```

# %%
event_5 = get_avg_write(["write","rw_write"],["Event_id: 5","Event : 4"],databases)

# %%
plot(event_5,"Average write query execution timings for RGB Event (without blob)")

# %% [markdown]
# # Event6: RGB Event (with blob)
# ```
# {
#     'image_base64': big_image_base64, #string 1 Mega bytes
#     'blob' : False, #boolean 24 bytes
#     'timestamp' : datetime.datetime.now() #datetime 48 bytes
# }
# ```

# %%
event_6 = get_avg_write(["write","rw_write"],["Event_id: 6","Event : 5"],databases)

# %%
plot(event_6,"Average write query execution timings for RGB Event (blob)")
