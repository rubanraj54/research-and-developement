# %%
# %run 'util.ipynb'
import os
from os import path
from sys import getsizeof
import datetime

# %%
df1_query_1 = get_avg_read(["read","rw_read"],"Query_id : 0",["arangodb","orientdb","influxdb","mysql"])
df2_query_1 = get_avg_read(["read","rw_read"],"Query_id : 0",["neo4j","couchdb","mongodb","cassandra"])

# %%
plot(df1_query_1,"Average read query execution timings to Get RGB events(without blob) for last 10 seconds")
plot(df2_query_1,"Average read query execution timings to Get RGB events(without blob) for last 10 seconds")
# Out:
# read(30hz)                0.929774
# read_with_write(30hz)     1.707113
# read(60hz)                0.978343
# read_with_write(60hz)     2.117540
# read(120hz)               1.081095
# read_with_write(120hz)    4.115395
# dtype: float64
# read(30hz)                0.001679
# read_with_write(30hz)     0.000443
# read(60hz)                0.001873
# read_with_write(60hz)     0.000386
# read(120hz)               0.002082
# read_with_write(120hz)    0.000606
# dtype: float64

# %%
df1_query_2 = get_avg_read(["read","rw_read"],"Query_id : 1",["arangodb","orientdb","influxdb","mysql"])
df2_query_2 = get_avg_read(["read","rw_read"],"Query_id : 1",["neo4j","couchdb","mongodb","cassandra"])

# %%
plot(df1_query_2,"Average read query execution timings to Get RGB events(with blob) for last 10 seconds")
plot(df2_query_2,"Average read query execution timings to Get RGB events(with blob) for last 10 seconds")
# Out:
# read(30hz)                0.894081
# read_with_write(30hz)     1.493137
# read(60hz)                0.964599
# read_with_write(60hz)     2.096993
# read(120hz)               1.070166
# read_with_write(120hz)    3.701578
# dtype: float64
# read(30hz)                0.001679
# read_with_write(30hz)     0.000400
# read(60hz)                0.001828
# read_with_write(60hz)     0.000465
# read(120hz)               0.002082
# read_with_write(120hz)    0.000629
# dtype: float64

# %%
df1_query_3 = get_avg_read(["read","rw_read"],"Query_id : 2",["arangodb","orientdb","influxdb","mysql"])
df2_query_3 = get_avg_read(["read","rw_read"],"Query_id : 2",["neo4j","couchdb","mongodb","cassandra"])

# %%
plot(df1_query_3,"Average read query execution timings to Get first 10 PoseEvents generated today")
plot(df2_query_3,"Average read query execution timings to Get first 10 PoseEvents generated today")

# %%
df1_query_4 = get_avg_read(["read","rw_read"],"Query_id : 3",["arangodb","orientdb","influxdb","mysql"])
df2_query_4 = get_avg_read(["read","rw_read"],"Query_id : 3",["neo4j","couchdb","mongodb","cassandra"])

# %%
plot(df1_query_4,"Average read query execution timings to Get all Location events generated between certain latitude and longitude range")
plot(df2_query_4,"Average read query execution timings to Get all Location events generated between certain latitude and longitude range")

# %% [markdown]
# Observations:
#
#    In cassandra, read with write takes less time than only read scenario
